# %%
import pandas as pd
import json
UniList=pd.read_csv('UniDetails.csv')
UniCourse=pd.read_csv('Courses.csv')
finaldict={}
user_input=input()
match=UniList[UniList["Institution Name"].str.contains(user_input,case=False,na=False)]
for i,rows in match.iterrows():
    name=rows['Institution Name']
    courses=UniCourse[UniCourse['Institution Name'].str.contains(name,case=False,na=False)].to_dict(orient='records')
    finaldict[rows['Institution Name']]={
        'University_Detail':rows,
        'Coursedetail':courses
    }
print(json.dumps(finaldict,indent=7))
# Out:
#  Wollongong
# C:\Users\aagam\AppData\Local\Temp\ipykernel_22228\1815299140.py:10: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   courses=UniCourse[UniCourse['Institution Name'].str.contains(name,case=False,na=False)].to_dict(orient='records')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 15
#      10     courses=UniCourse[UniCourse['Institution Name'].str.contains(name,case=False,na=False)].to_dict(orient='records')
#      11     finaldict[rows['Institution Name']]={
#      12         'University_Detail':rows,
#      13         'Coursedetail':courses
#      14     }
# ---> 15 print(json.dumps(finaldict,indent=7))
#
# File C:\SDKs\python\Lib\json\__init__.py:238, in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     232 if cls is None:
#     233     cls = JSONEncoder
#     234 return cls(
#     235     skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     236     check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237     separators=separators, default=default, sort_keys=sort_keys,
# --> 238     **kw).encode(obj)
#
# File C:\SDKs\python\Lib\json\encoder.py:200, in JSONEncoder.encode(self, o)
#     196         return encode_basestring(o)
#     197 # This doesn't pass the iterator directly to ''.join() because the
#     198 # exceptions aren't as detailed.  The list call should be roughly
#     199 # equivalent to the PySequence_Fast that ''.join() would do.
# --> 200 chunks = self.iterencode(o, _one_shot=True)
#     201 if not isinstance(chunks, (list, tuple)):
#     202     chunks = list(chunks)
#
# File C:\SDKs\python\Lib\json\encoder.py:261, in JSONEncoder.iterencode(self, o, _one_shot)
#     256 else:
#     257     _iterencode = _make_iterencode(
#     258         markers, self.default, _encoder, indent, floatstr,
#     259         self.key_separator, self.item_separator, self.sort_keys,
#     260         self.skipkeys, _one_shot)
# --> 261 return _iterencode(o, 0)
#
# File C:\SDKs\python\Lib\json\encoder.py:180, in JSONEncoder.default(self, o)
#     161 def default(self, o):
#     162     """Implement this method in a subclass such that it returns
#     163     a serializable object for ``o``, or calls the base implementation
#     164     (to raise a ``TypeError``).
#    (...)    178
#     179     """
# --> 180     raise TypeError(f'Object of type {o.__class__.__name__} '
#     181                     f'is not JSON serializable')
#
# TypeError: Object of type Series is not JSON serializable
